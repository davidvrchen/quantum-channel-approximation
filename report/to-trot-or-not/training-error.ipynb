# %%
from settings import *

# %%
errors_losses = np.load("trot_errors.npy")
errors_both= np.load("shea_errors.npy")

# %%
plt.semilogy(np.arange(len(errors_losses)), errors_losses, label="trotterized SHEA")
plt.semilogy(np.arange(len(errors_both)), errors_both, label="SHEA")
plt.xlabel("$iterations$")
plt.ylabel("$error$")
plt.legend()
plt.savefig("training-error-trot-or-not.pdf", bbox_inches="tight")
