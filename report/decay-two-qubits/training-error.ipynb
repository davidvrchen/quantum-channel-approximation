# %%
from settings import *

# %%
errors_losses = np.load("losses_errors.npy")
errors_both= np.load("both_errors.npy")

# %%
plt.semilogy(np.arange(len(errors_losses)), errors_losses, label="trotterized SHEA")
plt.semilogy(np.arange(len(errors_both)), errors_both, label="HEA")
plt.xlabel("$iterations$")
plt.ylabel("$error$")
plt.legend()
plt.savefig("training-error-q2-comparison.pdf", bbox_inches="tight")
